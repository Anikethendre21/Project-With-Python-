# %%
import numpy as np
import pandas as pd

# %%
file=pd.read_csv("C:\\Users\\ANIKET\\Pictures\\Myers Briggs Table_S1.csv")

# %%
df=file.drop(["E","S","N","T","F","J","P","PAIN 4","I"],axis=1)

# %%
df1=df.head(21)

# %%
bysex=df1.groupby("SEX")
bysex

# %%
female=bysex.get_group("Female")
female
# Out:
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITYLEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0      1   53      62     125  Female           Low     0.0     0.0     0.0
# 4      5   45      63     199  Female      Moderate     4.0     5.0     2.0
# 7      8   65      61     143  Female           Low     0.0     9.0     5.0
# 11    12   33      62     120  Female           Low     0.0     3.0     0.0
# 12    13   48      64     127  Female           Low     5.0     7.0     8.0
# 16    17   59      66     138  Female           Low     6.0     3.0     6.0
# 18    19   23      65     110  Female           Low     4.5     8.5     0.0
# 19    20   48      63     154  Female           Low     8.0     8.0     6.0
# 20    21   63      66     185  Female           Low     8.0     0.0     3.0
#
#     MBTI POSTURE
# 0   ESFJ       A
# 4   ENFJ       A
# 7   ESTJ       D
# 11  ISFJ       B
# 12  ESFJ       D
# 16  ESTJ       A
# 18  ESFP       B
# 19  ISFP       C
# 20  INFP       D

# %%
male=bysex.get_group("Male")
male
# Out:
#     S No  AGE  HEIGHT  WEIGHT   SEX ACTIVITYLEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 1      2   52      69     157  Male          High     7.0     8.0     5.0
# 2      3   30      69     200  Male          High     0.0     0.0     0.0
# 3      4   51      66     175  Male      Moderate     9.5     9.5     9.5
# 5      6   68      74     182  Male           Low     0.0     2.5     1.5
# 6      7   62      68     263  Male           Low     7.0    10.0    10.0
# 8      9   66      67     180  Male           Low     0.5     3.5     0.5
# 9     10   58      69     165  Male           Low     0.0     7.5     7.0
# 10    11   61      67     210  Male           Low     5.0     0.0     0.0
# 13    14   57      68     185  Male           Low     2.5     7.5     1.5
# 14    15   30      69     190  Male      Moderate     0.0     0.0     4.0
# 15    16   62      71     165  Male           Low     0.0     1.0     0.0
# 17    18   33      72     171  Male      Moderate     4.0     9.0     8.0
#
# ...

# %%
bysex.max()
# Out:
#         S No  AGE  HEIGHT  WEIGHT ACTIVITYLEVEL  PAIN 1  PAIN 2  PAIN 3  MBTI  \
# SEX
# Female    21   65      66     199      Moderate     8.0     9.0     8.0  ISFP
# Male      18   68      74     263      Moderate     9.5    10.0    10.0  ISTP
#
#        POSTURE
# SEX
# Female       D
# Male         D

# %%
for SEX,cdf in bysex:  #for(groupby atribute),(new variable) in (groupby variable):
    print(bysex)                  #print((groupby atribute))
    print(cdf)                    #print((new variable))
# Out:
# ...
#     S No  AGE  HEIGHT  WEIGHT     SEX ACTIVITYLEVEL  PAIN 1  PAIN 2  PAIN 3  \
# 0      1   53      62     125  Female           Low     0.0     0.0     0.0
# 4      5   45      63     199  Female      Moderate     4.0     5.0     2.0
# 7      8   65      61     143  Female           Low     0.0     9.0     5.0
# 11    12   33      62     120  Female           Low     0.0     3.0     0.0
# 12    13   48      64     127  Female           Low     5.0     7.0     8.0
# 16    17   59      66     138  Female           Low     6.0     3.0     6.0
# 18    19   23      65     110  Female           Low     4.5     8.5     0.0
# 19    20   48      63     154  Female           Low     8.0     8.0     6.0
# 20    21   63      66     185  Female           Low     8.0     0.0     3.0
#
#     MBTI POSTURE
# 0   ESFJ       A
# 4   ENFJ       A
# 7   ESTJ       D
# 11  ISFJ       B
# 12  ESFJ       D
# 16  ESTJ       A
# 18  ESFP       B
# 19  ISFP       C
# 20  INFP       D
# ...

# %%
pd.concat([df1.mean(),female.mean(),male.mean()],keys=["Total","Female","Male"])
dff
# Out:
# C:\Users\ANIKET\AppData\Local\Temp\ipykernel_5764\1332002421.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   pd.concat([df1.mean(),female.mean(),male.mean()],keys=["Total","Female","Male"])
#                    S No        AGE     HEIGHT      WEIGHT     PAIN 1  \
# Total  count  21.000000  21.000000  21.000000   21.000000  21.000000
#        mean   11.000000  50.809524  66.714286  168.761905   3.380952
#        std     6.204837  13.633118   3.466163   35.552644   3.323796
#        min     1.000000  23.000000  61.000000  110.000000   0.000000
#        25%     6.000000  45.000000  64.000000  143.000000   0.000000
#        50%    11.000000  53.000000  67.000000  171.000000   4.000000
#        75%    16.000000  62.000000  69.000000  185.000000   6.000000
# ...

# %%
dff=pd.concat([df1.describe(),female.describe(),male.describe()],keys=["Total","Female","Male"])

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.xlabel("ACTIVITYLEVEL")
plt.ylabel("Hight in CM")
plt.title("Hight Gorwth",color="g",size=30)
plt.bar(df1.ACTIVITYLEVEL,df1.WEIGHT,label="Weight",width=0.5)
plt.bar(df1.ACTIVITYLEVEL,df1.AGE,label="Age",width=0.5)
plt.legend()

# %%
plt.scatter(df1.WEIGHT,df1.AGE,c=np.random.rand(21),alpha=.3)
plt.xlabel("Weight")
plt.ylabel("AGE")
plt.title("Age wise Weight", c="#500", size= 30,
          fontname="Times New Roman",fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Age wise Weight')
