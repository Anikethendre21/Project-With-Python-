# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("dataset.csv")
df
# Out:
#       name  temp  wind       date
# 0    James  32.0  45.0   1/2/2020
# 1      NaN   NaN   NaN   1/6/2020
# 2     John -65.0  14.0        NaN
# 3  Michael   NaN -25.0  1/16/2020
# 4    Steve  37.0   NaN        NaN
# 5    David   NaN  52.0  1/20/2020
# 6  Richard  52.0   NaN        NaN
# 7      NaN   NaN  36.0        NaN
# 8   Thomas -42.0   NaN  1/26/2020
# 9  Charles  13.0  35.0  1/27/2020

# %%
ndf= df.replace(np.NaN, 0)
ndf
# Out:
#       name  temp  wind       date
# 0    James  32.0  45.0   1/2/2020
# 1        0   0.0   0.0   1/6/2020
# 2     John -65.0  14.0          0
# 3  Michael   0.0 -25.0  1/16/2020
# 4    Steve  37.0   0.0          0
# 5    David   0.0  52.0  1/20/2020
# 6  Richard  52.0   0.0          0
# 7        0   0.0  36.0          0
# 8   Thomas -42.0   0.0  1/26/2020
# 9  Charles  13.0  35.0  1/27/2020

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('gbdata.csv')
df
# Out:
#         day        city  temp  wind  event
# 0  1/1/2017  new yourk     32     6   Rain
# 1  1/2/2017      mumbai    36     5  Sunny
# 2  1/3/2017  new yourk     28     9   Rain
# 3  1/4/2017  new yourk     26     1    Fog
# 4  1/5/2017      mumbai    35     5   Rain
# 5  1/6/2017      mumbai    38     4  Sunny
# 6  1/7/2017  new yourk     30     7   Rain

# %%
g = df.groupby('city')
g

# %%
for city,cdf in g:
    print(city)
    print(cdf)
# Out:
# mumbai
#         day    city  temp  wind  event
# 1  1/2/2017  mumbai    36     5  Sunny
# 4  1/5/2017  mumbai    35     5   Rain
# 5  1/6/2017  mumbai    38     4  Sunny
# new yourk
#         day        city  temp  wind event
# 0  1/1/2017  new yourk     32     6  Rain
# 2  1/3/2017  new yourk     28     9  Rain
# 3  1/4/2017  new yourk     26     1   Fog
# 6  1/7/2017  new yourk     30     7  Rain

# %%
g.get_group("mumbai")
# Out:
#         day    city  temp  wind  event
# 1  1/2/2017  mumbai    36     5  Sunny
# 4  1/5/2017  mumbai    35     5   Rain
# 5  1/6/2017  mumbai    38     4  Sunny

# %%
g.max()
# Out:
#                  day  temp  wind  event
# city
# mumbai      1/6/2017    38     5  Sunny
# new yourk   1/7/2017    32     9   Rain

# %%
g.mean()
# Out:
#                  temp      wind
# city
# mumbai      36.333333  4.666667
# new yourk   29.000000  5.750000

# %%
g.describe()
# Out:
#             temp                                                     wind  \
#            count       mean       std   min   25%   50%   75%   max count
# city
# mumbai       3.0  36.333333  1.527525  35.0  35.5  36.0  37.0  38.0   3.0
# new yourk    4.0  29.000000  2.581989  26.0  27.5  29.0  30.5  32.0   4.0
#
#
#                 mean      std  min   25%  50%  75%  max
# city
# mumbai      4.666667  0.57735  4.0  4.50  5.0  5.0  5.0
# new yourk   5.750000  3.40343  1.0  4.75  6.5  7.5  9.0

# %%
# %matplotlib inline
g.plot()
# Out:
# city
# mumbai        AxesSubplot(0.125,0.11;0.775x0.77)
# new yourk     AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
import pandas as pd

# %%
ind=pd.DataFrame({
    "city":["mumbai","chennai","surat"],
    "temp":[10,15,20],
    "wind":[5,4,8]
})
ind
# Out:
#       city  temp  wind
# 0   mumbai    10     5
# 1  chennai    15     4
# 2    surat    20     8

# %%
usa=pd.DataFrame({
    "city":["vegus","alska","shikago"],
    "temp":[12,18,16],
    "wind":[7,9,6]
})
usa
# Out:
#       city  temp  wind
# 0    vegus    12     7
# 1    alska    18     9
# 2  shikago    16     6

# %%
df=pd.concat([ind,usa])
df
# Out:
#       city  temp  wind
# 0   mumbai    10     5
# 1  chennai    15     4
# 2    surat    20     8
# 0    vegus    12     7
# 1    alska    18     9
# 2  shikago    16     6

# %%
df=pd.concat([ind,usa],ignore_index=True)
df
# Out:
#       city  temp  wind
# 0   mumbai    10     5
# 1  chennai    15     4
# 2    surat    20     8
# 3    vegus    12     7
# 4    alska    18     9
# 5  shikago    16     6

# %%
df=pd.concat([ind,usa],keys=["ind","usa"])
df
# Out:
#           city  temp  wind
# ind 0   mumbai    10     5
#     1  chennai    15     4
#     2    surat    20     8
# usa 0    vegus    12     7
#     1    alska    18     9
#     2  shikago    16     6

# %%
df.loc["ind"]
# Out:
#       city  temp  wind
# 0   mumbai    10     5
# 1  chennai    15     4
# 2    surat    20     8

# %%
tmp=pd.DataFrame({
    "city":["mumbai","chennai","surat","delhi"],
    "temp":[10,15,20,21],
    
},index=[0,1,2,3])
tmp
# Out:
#       city  temp
# 0   mumbai    10
# 1  chennai    15
# 2    surat    20
# 3    delhi    21

# %%
wind=pd.DataFrame({
    "city":["mumbai","surat","chennai","pune"],
 
    "wind":[5,4,8,3]
},index=[0,2,1,3])
wind
# Out:
#       city  wind
# 0   mumbai     5
# 2    surat     4
# 1  chennai     8
# 3     pune     3

# %%
df=pd.concat([tmp,wind],axis=1)
df
# Out:
#       city  temp     city  wind
# 0   mumbai    10   mumbai     5
# 1  chennai    15  chennai     8
# 2    surat    20    surat     4
# 3    delhi    21     pune     3

# %%
tmp
# Out:
#       city  temp
# 0   mumbai    10
# 1  chennai    15
# 2    surat    20
# 3    delhi    21

# %%
s = pd.Series(["rain","due","dry"],name="event")
s
# Out:
# 0    rain
# 1     due
# 2     dry
# Name: event, dtype: object

# %%
pd.concat([tmp,s],axis=1)
# Out:
#       city  temp event
# 0   mumbai    10  rain
# 1  chennai    15   due
# 2    surat    20   dry
# 3    delhi    21   NaN

# %%
import pandas as pd
pd
# Out:
# <module 'pandas' from 'C:\\Users\\ANIKET\\anaconda3\\lib\\site-packages\\pandas\\__init__.py'>

# %%
df2=pd.merge(tmp,wind,on="city")
df2
# Out:
#       city  temp  wind
# 0   mumbai    10     5
# 1  chennai    15     8
# 2    surat    20     4

# %%
df2=pd.merge(tmp,wind,on="city",how="outer")
df2
# Out:
#       city  temp  wind
# 0   mumbai  10.0   5.0
# 1  chennai  15.0   8.0
# 2    surat  20.0   4.0
# 3    delhi  21.0   NaN
# 4     pune   NaN   3.0

# %%
df2=pd.merge(tmp,wind,on="city",how="left")
df2
# Out:
#       city  temp  wind
# 0   mumbai    10   5.0
# 1  chennai    15   8.0
# 2    surat    20   4.0
# 3    delhi    21   NaN

# %%
df2=pd.merge(tmp,wind,on="city",how="right")
df2
# Out:
#       city  temp  wind
# 0   mumbai  10.0     5
# 1    surat  20.0     4
# 2  chennai  15.0     8
# 3     pune   NaN     3

# %%
df2=pd.merge(tmp,wind,on="city",how="outer",indicator= True)
df2
# Out:
#       city  temp  wind      _merge
# 0   mumbai  10.0   5.0        both
# 1  chennai  15.0   8.0        both
# 2    surat  20.0   4.0        both
# 3    delhi  21.0   NaN   left_only
# 4     pune   NaN   3.0  right_only

# %%
uk=pd.DataFrame({
    "city":['a','b','c'],
    "temp":[12,18,16],
    "wind":[7,9,6]
})
uk
# Out:
#   city  temp  wind
# 0    a    12     7
# 1    b    18     9
# 2    c    16     6

# %%
ban=pd.DataFrame({
    "city":['b','c','d'],
    "temp":[10,15,20],
    "wind":[5,4,8]
})
ban
# Out:
#   city  temp  wind
# 0    b    10     5
# 1    c    15     4
# 2    d    20     8

# %%
df3=pd.merge(uk,ban,on='city',suffixes=("1st","2nd"))
df3
# Out:
#   city  temp1st  wind1st  temp2nd  wind2nd
# 0    b       18        9       10        5
# 1    c       16        6       15        4

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=[1,2,3,4,5,6,7]
y=[40,30,50,60,68,90,42]

# %%
plt.plot(x,y,color="green",linewith=4,)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11096\1730250389.py in <module>
# ----> 1 plt.plot(x,y,color="green",linewith=4,)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
# ...
